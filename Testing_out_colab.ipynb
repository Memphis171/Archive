# %% [markdown]
# <a href="https://colab.research.google.com/github/Memphis171/Archive/blob/branch-1/Testing_out_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
d = [1,2,3,4,5]
type(d)
# Out:
# list

# %% [markdown]
# Hello

# %%
1==2
# Out:
# False

# %% [markdown]
# # Hi

# %% [markdown]
# ##hi2
